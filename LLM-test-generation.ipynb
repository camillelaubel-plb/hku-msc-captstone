# %%
pip install google-generativeai
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import google.generativeai as genai

genai.configure(api_key="AIzaSyCQiW8uyewgcfxWfc-jROWUOaieo0tLYg0")

# Set up the model
generation_config = {
  "temperature": 1,
  "top_p": 0.95,
  "top_k": 0,
  "max_output_tokens": 8192,
}

safety_settings = [
  {
    "category": "HARM_CATEGORY_HARASSMENT",
    "threshold": "BLOCK_MEDIUM_AND_ABOVE"
  },
  {
    "category": "HARM_CATEGORY_HATE_SPEECH",
    "threshold": "BLOCK_MEDIUM_AND_ABOVE"
  },
  {
    "category": "HARM_CATEGORY_SEXUALLY_EXPLICIT",
    "threshold": "BLOCK_MEDIUM_AND_ABOVE"
  },
  {
    "category": "HARM_CATEGORY_DANGEROUS_CONTENT",
    "threshold": "BLOCK_MEDIUM_AND_ABOVE"
  },
]

model = genai.GenerativeModel(model_name="gemini-1.5-pro-latest",
                              generation_config=generation_config,
                              safety_settings=safety_settings)


response = model.generate_content("""Generate me python unit test for: 
                                    num1 = int(input("Enter the first integer: "))
                                    num2 = int(input("Enter the second integer: "))

                                    sum_result = num1 + num2
                                    print("The sum of", num1, "and", num2, "is:", sum_result)
                                  """)
print(response.text)
# Out:
# ```python
# import unittest
# import io
# from unittest.mock import patch
#
# class TestSum(unittest.TestCase):
#
#     @patch('builtins.input', side_effect=['5', '10'])  # Simulate user input
#     def test_sum_positive(self, mock_input):
#         captured_output = io.StringIO()  # Capture printed output
#         with patch('sys.stdout', captured_output):
#             # Code under test (assuming it's in a function named calculate_sum)
#             num1 = int(input("Enter the first integer: "))
#             num2 = int(input("Enter the second integer: "))
#             sum_result = num1 + num2
#             print("The sum of", num1, "and", num2, "is:", sum_result)
#
#         self.assertEqual(captured_output.getvalue().strip(), "The sum of 5 and 10 is: 15")
#
#     @patch('builtins.input', side_effect=['-3', '7'])  # Simulate user input
#     def test_sum_negative_positive(self, mock_input):
#         captured_output = io.StringIO()
# ...

# %%
import unittest
import io
from unittest.mock import patch

class TestSum(unittest.TestCase):

    @patch('sys.stdout', new_callable=io.StringIO)
    def test_sum_positive_numbers(self, mock_stdout):
        # Simulate user input
        user_input = ["5", "10"]
        with patch('builtins.input', side_effect=user_input):
            # Call the code you want to test
            # (assuming it's in a function called calculate_sum)
            num1 = int(input("Enter the first integer: "))
            num2 = int(input("Enter the second integer: "))

            sum_result = num1 + num2
            print("The sum of", num1, "and", num2, "is:", sum_result)

        # Check the output
        self.assertEqual(mock_stdout.getvalue(), "The sum of 5 and 10 is: 15\n")

    @patch('sys.stdout', new_callable=io.StringIO)
    def test_sum_negative_numbers(self, mock_stdout):
        user_input = ["-3", "-7"]
        with patch('builtins.input', side_effect=user_input):
            num1 = int(input("Enter the first integer: "))
            num2 = int(input("Enter the second integer: "))

            sum_result = num1 + num2
            print("The sum of", num1, "and", num2, "is:", sum_result)

        self.assertEqual(mock_stdout.getvalue(), "The sum of -3 and -7 is: -10\n")

    # Add more test cases for different scenarios, such as:
    # - Sum of a positive and a negative number
    # - Sum involving zero
    # - Handling invalid input (e.g., non-numeric input)


if __name__ == '__main__':
        unittest.main(argv=['first-arg-is-ignored'], exit=False)
# Out:
# ..
# ----------------------------------------------------------------------
# Ran 2 tests in 0.006s
#
# OK
